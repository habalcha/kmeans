# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("Mopsi_Location_Data.csv", sep= " ", names = ['longitude', 'longitude5', 'latitude'])

df = df.loc[:, ['longitude', 'latitude']]

df
# Out:
#        longitude  latitude
# 0         625983    297439
# 1         626146    297440
# 2         626144    297456
# 3         626004    297394
# 4         626018    297437
# ...          ...       ...
# 13462     626042    297444
# 13463     625977    297443
# 13464     626050    297404
# 13465     625995    297426
# 13466     625982    297431
#
# [13467 rows x 2 columns]

# %%
from sklearn.cluster import KMeans

n_clusters = 10
n_init = 10
max_iter = 100
tol = 0.0001
random_state = 663
kmeans = KMeans(n_clusters=n_clusters, n_init=n_init, max_iter=max_iter, tol=tol, random_state=random_state)
mean_distance = kmeans.fit_transform(df)
plt.figure()
plt.plot(x = mean_distance[0,:], y = mean_distance[:,1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-df69c77b6b32> in <module>
#       9 mean_distance = kmeans.fit_transform(df)
#      10 plt.figure()
# ---> 11 plt.plot(x = mean_distance[0,:], y = mean_distance[:,1])
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
# ...

# %%
from sklearn.cluster import DBSCAN

max_dist = 7000
hoodsize = 50
cluster = DBSCAN(eps = max_dist, min_samples = hoodsize)
cluster.fit(df)

plt.figure()
plt.scatter(x = 'latitude', y = 'longitude', c = cluster.labels_, data = df)
plt.show()

# %%
sum(cluster.labels_)/cluster.labels_.shape[0]
# Out:
# 0.017895596643647434
